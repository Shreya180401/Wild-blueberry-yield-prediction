# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreya180401/Wild-blueberry-yield-prediction/blob/main/Blueberry_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("/content/Wild blueberry yield prediction.csv")

# %%
ds.head()
# Out:
#    Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  fruitset  \
# 0     0       37.5      0.75     0.25     0.25   0.25         16.0  0.410652
# 1     1       37.5      0.75     0.25     0.25   0.25          1.0  0.444254
# 2     2       37.5      0.75     0.25     0.25   0.25         16.0  0.383787
# 3     3       37.5      0.75     0.25     0.25   0.25          1.0  0.407564
# 4     4       37.5      0.75     0.25     0.25   0.25         24.0  0.354413
#
#    fruitmass      seeds        yield
# 0   0.408159  31.678898  3813.165795
# 1   0.425458  33.449385  4947.605663
# 2   0.399172  30.546306  3866.798965
# 3   0.408789  31.562586  4303.943030
# 4   0.382703  28.873714  3436.493543

# %%
ds.columns
# Out:
# Index(['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'RainingDays', 'fruitset', 'fruitmass', 'seeds', 'yield'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row#         777 non-null    int64
#  1   clonesize    777 non-null    float64
#  2   honeybee     777 non-null    float64
#  3   bumbles      777 non-null    float64
#  4   andrena      777 non-null    float64
#  5   osmia        777 non-null    float64
#  6   RainingDays  777 non-null    float64
#  7   fruitset     777 non-null    float64
#  8   fruitmass    777 non-null    float64
#  9   seeds        777 non-null    float64
#  10  yield        777 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 66.9 KB

# %%
ds.describe()
# Out:
#              Row#   clonesize    honeybee     bumbles     andrena       osmia  \
# count  777.000000  777.000000  777.000000  777.000000  777.000000  777.000000
# mean   388.000000   18.767696    0.417133    0.282389    0.468817    0.562062
# std    224.444871    6.999063    0.978904    0.066343    0.161052    0.169119
# min      0.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    194.000000   12.500000    0.250000    0.250000    0.380000    0.500000
# 50%    388.000000   12.500000    0.250000    0.250000    0.500000    0.630000
# 75%    582.000000   25.000000    0.500000    0.380000    0.630000    0.750000
# max    776.000000   40.000000   18.430000    0.585000    0.750000    0.750000
#
#        RainingDays    fruitset   fruitmass       seeds        yield
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean     18.309292    0.502121    0.445983   36.122432  6012.849165
# ...

# %%
ds.dtypes
# Out:
# Row#             int64
# clonesize      float64
# honeybee       float64
# bumbles        float64
# andrena        float64
# osmia          float64
# RainingDays    float64
# fruitset       float64
# fruitmass      float64
# seeds          float64
# yield          float64
# dtype: object

# %%
ds.isnull().any()
# Out:
# Row#           False
# clonesize      False
# honeybee       False
# bumbles        False
# andrena        False
# osmia          False
# RainingDays    False
# fruitset       False
# fruitmass      False
# seeds          False
# yield          False
# dtype: bool

# %%
# Checking missing values
plt.figure(figsize=(10,6))
sns.heatmap(ds.isnull(), cmap="viridis", cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(ds.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlations")
plt.show()

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
ds.value_counts()
# Out:
# Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  fruitset  fruitmass  seeds      yield
# 776   20.0       0.537     0.117    0.409    0.058  24.0         0.384646  0.392303   29.742583  3943.131681    1
# 0     37.5       0.750     0.250    0.250    0.250  16.0         0.410652  0.408159   31.678898  3813.165795    1
# 1     37.5       0.750     0.250    0.250    0.250  1.0          0.444254  0.425458   33.449385  4947.605663    1
# 2     37.5       0.750     0.250    0.250    0.250  16.0         0.383787  0.399172   30.546306  3866.798965    1
# 3     37.5       0.750     0.250    0.250    0.250  1.0          0.407564  0.408789   31.562586  4303.943030    1
#                                                                                                                ..
# 13    37.5       0.250     0.250    0.250    0.250  16.0         0.364881  0.395636   30.124627  3720.711588    1
# ...

# %%
# Boxplot for outlier detection
plt.figure(figsize=(8,5))
sns.boxplot(x=ds["yield"])
plt.title("Boxplot of Feature")
plt.show()

# %%
# Pairplot for feature relationships
sns.pairplot(ds, hue="yield")
plt.show()

# %%
#Splitting data
X = ds.drop("yield", axis=1)
y = ds["yield"]

# %%
X
# Out:
#      Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  \
# 0       0       37.5     0.750    0.250    0.250  0.250        16.00
# 1       1       37.5     0.750    0.250    0.250  0.250         1.00
# 2       2       37.5     0.750    0.250    0.250  0.250        16.00
# 3       3       37.5     0.750    0.250    0.250  0.250         1.00
# 4       4       37.5     0.750    0.250    0.250  0.250        24.00
# ..    ...        ...       ...      ...      ...    ...          ...
# 772   772       10.0     0.537    0.117    0.409  0.058         3.77
# 773   773       40.0     0.537    0.117    0.409  0.058         3.77
# 774   774       20.0     0.537    0.117    0.409  0.058        24.00
# 775   775       20.0     0.537    0.117    0.409  0.058         3.77
# 776   776       20.0     0.537    0.117    0.409  0.058        24.00
#
#      fruitset  fruitmass      seeds
# 0    0.410652   0.408159  31.678898
# 1    0.444254   0.425458  33.449385
# ...

# %%
y
# Out:
# 0      3813.165795
# 1      4947.605663
# 2      3866.798965
# 3      4303.943030
# 4      3436.493543
#           ...
# 772    5333.873335
# 773    3373.436842
# 774    4203.027624
# 775    4166.299735
# 776    3943.131681
# Name: yield, Length: 777, dtype: float64

# %%
#Train-Test-Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Scaling
from sklearn.preprocessing import StandardScaler

# %%
#creating object
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Squared Error (MSE): 47774.099248985585
# Root Mean Squared Error (RMSE): 218.5728694257034
# R-squared (R2): 0.975420138900749
# Mean Absolute Error (MAE): 173.3406976750909

# %%
#For loop
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr = LinearRegression()
r = Ridge()
l = Lasso()
en = ElasticNet()
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor()
svr = SVR()
rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()

# %%
algos = [lr,r,l,en,knr,dtr,svr,rfr,abr,gbr]
names = ["Linear Regression", "Ridge", "Lasso", "ElasticNet", "KNeighbors", "Decision Tree", "SVR", "RandomForest", "AdaBoost", "Gradient Boosting"]

# %%
for i, j in  zip(algos,names):
  i.fit(X_train, y_train)
  pred = i.predict(X_test)
  print(j)
  from sklearn.metrics import r2_score
  print(r2_score(y_test,pred))
  print("#" *40)
# Out:
# Linear Regression
# 0.9903848340714277
# ########################################
# Ridge
# 0.9901906122120023
# ########################################
# Lasso
# 0.9905113243948461
# ########################################
# ElasticNet
# 0.9520980068945031
# ########################################
# KNeighbors
# 0.9606175520123562
# ########################################
# Decision Tree
# 0.9790187630156018
# ########################################
# SVR
# 0.03178238673569056
# ########################################
# RandomForest
# 0.9865510395097689
# ########################################
# AdaBoost
# 0.9721561999512471
# ########################################
# Gradient Boosting
# 0.9889378899277163
# ########################################

# %%
#Hyper-tuning
from sklearn.model_selection import GridSearchCV
para = {"n_estimators" : [35,67,108], "criterion" : ["squared_error", "absolute_error", "poisson"], "max_depth" : [4], "bootstrap" : [True]}

# %%
gsv = GridSearchCV(rfr, para, cv=7, scoring = "r2")

# %%
gsv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True],
#                          'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [4], 'n_estimators': [35, 67, 108]},
#              scoring='r2')

# %%
gsv.best_params_ #to check the parameters used
# Out:
# {'bootstrap': True,
#  'criterion': 'squared_error',
#  'max_depth': 4,
#  'n_estimators': 108}

# %%
y_pred = gsv.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.975420138900749

# %%
# Predict on training and test data
y_train_pred = rfr.predict(X_train)
y_test_pred = rfr.predict(X_test)

# %%
# Calculate metrics for training set
train_r2 = r2_score(y_train, y_train_pred)
train_mse = mean_squared_error(y_train, y_train_pred)
train_rmse = train_mse**0.5

# Calculate metrics for test set
test_r2 = r2_score(y_test, y_test_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
test_rmse = test_mse**0.5

# Print results
print(f"Training R² Score: {train_r2:.4f}")
print(f"Testing R² Score: {test_r2:.4f}")
print(f"Training RMSE: {train_rmse:.4f}")
print(f"Testing RMSE: {test_rmse:.4f}")
# Out:
# Training R² Score: 0.9979
# Testing R² Score: 0.9866
# Training RMSE: 61.0944
# Testing RMSE: 161.6780

# %% [markdown]
# # **Conclusion: Blueberry Yield Prediction Model**
#
# The goal of this project was to develop a machine learning model to predict Blueberry yield based on various environmental and agricultural factors. We performed Exploratory Data Analysis (EDA) using Seaborn & Matplotlib. The model was trained and evaluated using R² Score and RMSE, achieving:
#
# *   Training R² Score: 0.9979, Testing R² Score: 0.9866
#
# *   Training RMSE: 61.09, Testing RMSE: 161.67
#
#
#
#  The high R² score indicates that our model can accurately predict yield, which is crucial for farmers and agricultural planners to optimize production, minimize losses, and make data-driven decisions.
#
#
# There was slight overfitting, but the model performed well in predicting yield. Future improvements can focus on outlier handling, testing alternative models, and incorporating additional environmental factors.
#
#
#
#   🔹 Overall, this project demonstrates how predictive modeling can support precision agriculture, enabling better resource management and improved yield forecasting
