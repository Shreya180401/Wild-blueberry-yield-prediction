# %%
import pandas as pd

# %%
ds = pd.read_csv("/content/Wild blueberry yield prediction.csv")

# %%
ds.head()
# Out:
#    Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  fruitset  \
# 0     0       37.5      0.75     0.25     0.25   0.25         16.0  0.410652
# 1     1       37.5      0.75     0.25     0.25   0.25          1.0  0.444254
# 2     2       37.5      0.75     0.25     0.25   0.25         16.0  0.383787
# 3     3       37.5      0.75     0.25     0.25   0.25          1.0  0.407564
# 4     4       37.5      0.75     0.25     0.25   0.25         24.0  0.354413
#
#    fruitmass      seeds        yield
# 0   0.408159  31.678898  3813.165795
# 1   0.425458  33.449385  4947.605663
# 2   0.399172  30.546306  3866.798965
# 3   0.408789  31.562586  4303.943030
# 4   0.382703  28.873714  3436.493543

# %%
ds.columns
# Out:
# Index(['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'RainingDays', 'fruitset', 'fruitmass', 'seeds', 'yield'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row#         777 non-null    int64
#  1   clonesize    777 non-null    float64
#  2   honeybee     777 non-null    float64
#  3   bumbles      777 non-null    float64
#  4   andrena      777 non-null    float64
#  5   osmia        777 non-null    float64
#  6   RainingDays  777 non-null    float64
#  7   fruitset     777 non-null    float64
#  8   fruitmass    777 non-null    float64
#  9   seeds        777 non-null    float64
#  10  yield        777 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 66.9 KB

# %%
ds.describe()
# Out:
#              Row#   clonesize    honeybee     bumbles     andrena       osmia  \
# count  777.000000  777.000000  777.000000  777.000000  777.000000  777.000000
# mean   388.000000   18.767696    0.417133    0.282389    0.468817    0.562062
# std    224.444871    6.999063    0.978904    0.066343    0.161052    0.169119
# min      0.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    194.000000   12.500000    0.250000    0.250000    0.380000    0.500000
# 50%    388.000000   12.500000    0.250000    0.250000    0.500000    0.630000
# 75%    582.000000   25.000000    0.500000    0.380000    0.630000    0.750000
# max    776.000000   40.000000   18.430000    0.585000    0.750000    0.750000
#
#        RainingDays    fruitset   fruitmass       seeds        yield
# count   777.000000  777.000000  777.000000  777.000000   777.000000
# mean     18.309292    0.502121    0.445983   36.122432  6012.849165
# ...

# %%
ds.dtypes
# Out:
# Row#             int64
# clonesize      float64
# honeybee       float64
# bumbles        float64
# andrena        float64
# osmia          float64
# RainingDays    float64
# fruitset       float64
# fruitmass      float64
# seeds          float64
# yield          float64
# dtype: object

# %%
ds.isnull()
# Out:
#       Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  \
# 0    False      False     False    False    False  False        False
# 1    False      False     False    False    False  False        False
# 2    False      False     False    False    False  False        False
# 3    False      False     False    False    False  False        False
# 4    False      False     False    False    False  False        False
# ..     ...        ...       ...      ...      ...    ...          ...
# 772  False      False     False    False    False  False        False
# 773  False      False     False    False    False  False        False
# 774  False      False     False    False    False  False        False
# 775  False      False     False    False    False  False        False
# 776  False      False     False    False    False  False        False
#
#      fruitset  fruitmass  seeds  yield
# 0       False      False  False  False
# 1       False      False  False  False
# ...

# %%
ds.isnull().any()
# Out:
# Row#           False
# clonesize      False
# honeybee       False
# bumbles        False
# andrena        False
# osmia          False
# RainingDays    False
# fruitset       False
# fruitmass      False
# seeds          False
# yield          False
# dtype: bool

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds.value_counts()
# Out:
# Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  fruitset  fruitmass  seeds      yield
# 0     37.5       0.750     0.250    0.250    0.250  16.0         0.410652  0.408159   31.678898  3813.165795    1
# 534   25.0       0.500     0.250    0.500    0.630  34.0         0.473459  0.437681   34.724834  5439.421503    1
# 512   25.0       0.500     0.250    0.500    0.500  34.0         0.320565  0.372338   27.719772  3238.028147    1
# 513   25.0       0.500     0.250    0.500    0.500  16.0         0.497275  0.450750   36.362937  5964.791108    1
# 514   25.0       0.500     0.250    0.500    0.500  1.0          0.527190  0.463020   37.629774  6526.988187    1
#                                                                                                                ..
# 262   12.5       0.250     0.250    0.630    0.500  1.0          0.586304  0.490981   40.922101  7570.608619    1
# ...

# %%
#Splitting data

X = ds.drop("yield", axis=1)
y = ds["yield"]

# %%
X
# Out:
#      Row#  clonesize  honeybee  bumbles  andrena  osmia  RainingDays  \
# 0       0       37.5     0.750    0.250    0.250  0.250        16.00
# 1       1       37.5     0.750    0.250    0.250  0.250         1.00
# 2       2       37.5     0.750    0.250    0.250  0.250        16.00
# 3       3       37.5     0.750    0.250    0.250  0.250         1.00
# 4       4       37.5     0.750    0.250    0.250  0.250        24.00
# ..    ...        ...       ...      ...      ...    ...          ...
# 772   772       10.0     0.537    0.117    0.409  0.058         3.77
# 773   773       40.0     0.537    0.117    0.409  0.058         3.77
# 774   774       20.0     0.537    0.117    0.409  0.058        24.00
# 775   775       20.0     0.537    0.117    0.409  0.058         3.77
# 776   776       20.0     0.537    0.117    0.409  0.058        24.00
#
#      fruitset  fruitmass      seeds
# 0    0.410652   0.408159  31.678898
# 1    0.444254   0.425458  33.449385
# ...

# %%
y
# Out:
# 0      3813.165795
# 1      4947.605663
# 2      3866.798965
# 3      4303.943030
# 4      3436.493543
#           ...
# 772    5333.873335
# 773    3373.436842
# 774    4203.027624
# 775    4166.299735
# 776    3943.131681
# Name: yield, Length: 777, dtype: float64

# %%
#Train-Test-Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Scaling
from sklearn.preprocessing import StandardScaler

# %%
#creating object
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#For loop
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr = LinearRegression()
r = Ridge()
l = Lasso()
en = ElasticNet()
knr = KNeighborsRegressor()
dtr = DecisionTreeRegressor()
svr = SVR()
rfr = RandomForestRegressor()
abr = AdaBoostRegressor()
gbr = GradientBoostingRegressor()

# %%
algos = [lr,r,l,en,knr,dtr,svr,rfr,abr,gbr]
names = ["Linear Regression", "Ridge", "Lasso", "ElasticNet", "KNeighbors", "Decision Tree", "SVR", "RandomForest", "AdaBoost", "Gradient Boosting"]

# %%
for i, j in  zip(algos,names):
  i.fit(X_train, y_train)
  pred = i.predict(X_test)
  print(j)
  from sklearn.metrics import r2_score
  print(r2_score(y_test,pred))
  print("#" *40)
# Out:
# Linear Regression
# 0.9903848340714277
# ########################################
# Ridge
# 0.9901906122120023
# ########################################
# Lasso
# 0.9905113243948461
# ########################################
# ElasticNet
# 0.9520980068945031
# ########################################
# KNeighbors
# 0.9606175520123562
# ########################################
# Decision Tree
# 0.9780798994665253
# ########################################
# SVR
# 0.03178238673569056
# ########################################
# RandomForest
# 0.9864613250548988
# ########################################
# AdaBoost
# 0.9730381379447552
# ########################################
# Gradient Boosting
# 0.9890431196115412
# ########################################

# %%
#Hyper-tuning
from sklearn.model_selection import GridSearchCV
para = {"n_estimators" : [35,67,108], "criterion" : ["squared_error", "absolute_error", "poisson"], "max_depth" : [4], "bootstrap" : [True]}

# %%
gsv = GridSearchCV(rfr, para, cv=7, scoring = "r2")

# %%
gsv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True],
#                          'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [4], 'n_estimators': [35, 67, 108]},
#              scoring='r2')

# %%
gsv.best_params_ #to check the parameters used
# Out:
# {'bootstrap': True,
#  'criterion': 'squared_error',
#  'max_depth': 4,
#  'n_estimators': 35}

# %%
y_pred = gsv.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9754915630695862

# %%
#Pickling
import pickle

# %%
pickle.dump(scaler, open("Standard_Scaler.pkl", "wb"))  #file is set to be in write by mode
pickle.dump(l, open("RandomForest.pkl", "wb"))
